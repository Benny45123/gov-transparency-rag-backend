# %%
import getpass
import os
from dotenv import load_dotenv
load_dotenv()

if not os.getenv("GEMINI_API_KEY"):
    os.environ["GEMINI_API_KEY"] = getpass.getpass("Enter your Google API key: ")
else:
    print("Using existing GEMINI_API_KEY environment variable.")
# Out:
# Using existing GEMINI_API_KEY environment variable.

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings

# %%
embedding_model=GoogleGenerativeAIEmbeddings(model="gemini-embedding-001")

# %%
def embed_text(text):
    embedding = embedding_model.embed_query(text)
    return embedding
text="This is a sample text to be embedded."
